# %%
from sqlalchemy import create_engine
import pymysql
import os
import json
from sqlalchemy import text
from datetime import datetime
import pandas as pd

# %%
user_name = os.environ.get('DB_USER')
user_pass = os.environ.get('DB_PASS')
user_host = os.environ.get('DB_PATH')
user_port = 3306
user_db = os.environ.get('DB_NAME')
print(f"'[user_name]': {user_name}, '[user_pass]': {user_pass}, '[user_host]': {user_host}, '[user_port]': {user_port}, '[user_db]': {user_db}")
# Out:
# '[user_name]': czpqmrra_blog-admin, '[user_pass]': C[dcWZa!-p[h, '[user_host]': 103.172.92.27, '[user_port]': 3306, '[user_db]': czpqmrra_blog

# %%
try:
    engine = create_engine('mysql+pymysql://'+f'{user_name}:{user_pass}@{user_host}:{user_port}/{user_db}')
    print(engine)
except Exception as e:
    print(e)
else:
    try:
        connection = engine.connect()
        print(connection)
    except Exception as e:
        print(e)
# Out:
# Engine(mysql+pymysql://czpqmrra_blog-admin:***@103.172.92.27:3306/czpqmrra_blog)
# ...

# %%
def save_pincode_to_database():
    '''it atomically save pincode to database.
    dont run it in production'''
    data = pd.read_csv('data/pincode.csv')
    header = list(data.columns)
    print(header)
    # replace all header to small letter and space with underscore
    header = [x.replace(' ', '_') for x in header]
    header = [x.lower() for x in header]
    print(header)
    data.columns = header
    print(data.columns)
    # create id column
    data['id'] = range(1, len(data) + 1)
    # create a table
    try:
        data.to_sql(name='pincode', con=engine, if_exists='replace', index=False)
    except:
        print(e)
        connection.rollback()
# save_pincode_to_database()
# Out:
# ['officename', 'pincode', 'officeType', 'Deliverystatus', 'divisionname', 'regionname', 'circlename', 'Taluk', 'Districtname', 'statename', 'Telephone', 'Related Suboffice', 'Related Headoffice', 'longitude', 'latitude']
# ['officename', 'pincode', 'officetype', 'deliverystatus', 'divisionname', 'regionname', 'circlename', 'taluk', 'districtname', 'statename', 'telephone', 'related_suboffice', 'related_headoffice', 'longitude', 'latitude']
# Index(['officename', 'pincode', 'officetype', 'deliverystatus', 'divisionname',
#        'regionname', 'circlename', 'taluk', 'districtname', 'statename',
#        'telephone', 'related_suboffice', 'related_headoffice', 'longitude',
#        'latitude'],
#       dtype='object')

# %%
# read data from database
def read_pincode_from_database(pincode):
    '''it read pincode from database
    dont run it in production'''
    try:
        df = pd.read_sql(text(f'SELECT * FROM pincode WHERE pincode = {pincode}'), engine)
        print(df)
        print(df.columns)
    except Exception as e:
        print(e)
    else:
        return df

read_pincode_from_database(700135)
# Out:
#                 officename  pincode officetype deliverystatus divisionname  \
# 0        Akandakeshari B.O   700135        B.O       Delivery      Barasat
# 1                 Bagu B.O   700135        B.O       Delivery      Barasat
# 2             Chandpur B.O   700135        B.O       Delivery      Barasat
# 3             Hatisala B.O   700135        B.O       Delivery      Barasat
# 4           Kadampukur B.O   700135        B.O       Delivery      Barasat
# 5              Kamduni B.O   700135        B.O       Delivery      Barasat
# 6         Kashinathpur B.O   700135        B.O       Delivery      Barasat
# 7              Lauhati B.O   700135        B.O       Delivery      Barasat
# 8          Machibhanga B.O   700135        B.O       Delivery      Barasat
# 9           Matiaghata B.O   700135        B.O       Delivery      Barasat
# 10              Paikan B.O   700135        B.O       Delivery      Barasat
# ...
